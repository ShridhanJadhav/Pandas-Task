# %%
import pandas as pd

# %%
a = pd.read_csv(r"C:\Users\Admin\Downloads\Titanic.csv")

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
a['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 34.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
a['Age'].nunique()
# Out:
# 88

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 892 entries, 0 to 891
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  892 non-null    int64
#  1   Survived     892 non-null    int64
#  2   col4         892 non-null    int64
#  3   Pclass       892 non-null    int64
#  4   Name         892 non-null    object
#  5   Sex          892 non-null    object
#  6   Age          715 non-null    float64
#  7   SibSp        892 non-null    int64
#  8   Parch        892 non-null    int64
#  9   Ticket       892 non-null    object
#  10  Fare         892 non-null    float64
#  11  Cabin        892 non-null    object
#  12  Embarked     892 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 97.6+ KB

# %%
a.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 1. First convert the data types of the all columns to object and then try to convert them back to appropriate data types.

# %%
a = a.astype(str)
a.dtypes
# Out:
# PassengerId    object
# Survived       object
# Pclass         object
# Name           object
# Sex            object
# Age            object
# SibSp          object
# Parch          object
# Ticket         object
# Fare           object
# Cabin          object
# Embarked       object
# dtype: object

# %%
a = a.astype({'PassengerId': int , 'Survived': int , 'Pclass': int,  'Age': float , 'SibSp': int,
       'Parch': int,  'Fare': float,  })
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 2. Add a single column to the data set
# a. based on the existing columns

# %%
a['col1']= a['Age']*a['Fare']
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 3. Add multiple columns.

# %%
x = a['PassengerId'] + a['Survived']
y = a['Survived'] + a['Pclass']

a['col2'] = x
a['col3'] = y

a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 4. Add column at a specific column position.

# %%
a.insert(2,'col4',x,True)
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3              4         1     5       1
# 4              5         0     5       3
# ..           ...       ...   ...     ...
# 886          887         0   887       2
# 887          888         1   889       1
# 888          889         0   889       3
# 889          890         1   891       1
# 890          891         0   891       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### 5. Drop the single column created in q2.

# %%
a.drop(['col1'], axis=1, inplace=True)

# %%
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3              4         1     5       1
# 4              5         0     5       3
# ..           ...       ...   ...     ...
# 886          887         0   887       2
# 887          888         1   889       1
# 888          889         0   889       3
# 889          890         1   891       1
# 890          891         0   891       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### 6. Drop multiple columns created in q3.

# %%
a.drop(['col2', 'col3'], axis=1, inplace=True)

# %%
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3              4         1     5       1
# 4              5         0     5       3
# ..           ...       ...   ...     ...
# 886          887         0   887       2
# 887          888         1   889       1
# 888          889         0   889       3
# 889          890         1   891       1
# 890          891         0   891       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### 7. add a single row to the data set

# %%
a.loc[len(a)] = [892, 0 , 892 , 3, 'abcd', 'famale', 34.0, 0 , 2, 35879 , 10.7500,  'C149', 'z' ]
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3              4         1     5       1
# 4              5         0     5       3
# ..           ...       ...   ...     ...
# 887          888         1   889       1
# 888          889         0   889       3
# 889          890         1   891       1
# 890          891         0   891       3
# 891          892         0   892       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### 8. Add multiple rows.

# %%
a.columns
# Out:
# Index(['PassengerId', 'Survived', 'col4', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new = pd.DataFrame([{'PassengerId': 893, 'Survived': 0, 'col4':893, 'Pclass':4, 'Name':'xyz', 'Sex': 'female', 'Age':88.0,
       'SibSp':1, 'Parch':2, 'Ticket': 35879, 'Fare': 90.1256, 'Cabin':'C152', 'Embarked':x},
                   {'PassengerId': 894, 'Survived': 0, 'col4':894, 'Pclass':4, 'Name':'xyz', 'Sex': 'female', 'Age':88.0,
       'SibSp':1, 'Parch':2, 'Ticket': 35879, 'Fare': 90.1256, 'Cabin':'C152', 'Embarked':x}])
a = pd.concat([a,new], ignore_index=True)

# %%
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3              4         1     5       1
# 4              5         0     5       3
# ..           ...       ...   ...     ...
# 889          890         1   891       1
# 890          891         0   891       3
# 891          892         0   892       3
# 892          893         0   893       4
# 893          894         0   894       4
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### 9.Add row at a specific column position.

# %%
a.loc[2.2]= [892, 0 , 892 , 3, 'abcd', 'famale', 34.0, 0 , 2, 35879 , 10.7500,  'C149', 'z' ]
a = a.sort_index().reset_index(drop=True)
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3            892         0   892       3
# 4              4         1     5       1
# ..           ...       ...   ...     ...
# 890          890         1   891       1
# 891          891         0   891       3
# 892          892         0   892       3
# 893          893         0   893       4
# 894          894         0   894       4
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                                                 abcd  famale  34.0      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ### 10.Drop the single row created in q7.

# %%
a.drop(892, axis=0, inplace=True)
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3            892         0   892       3
# 4              4         1     5       1
# ..           ...       ...   ...     ...
# 889          889         0   889       3
# 890          890         1   891       1
# 891          891         0   891       3
# 893          893         0   893       4
# 894          894         0   894       4
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                                                 abcd  famale  34.0      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ### 11. Drop multiple rows created in q8.

# %%
a.drop([893,894], axis=0, inplace=True)
a
# Out:
#      PassengerId  Survived  col4  Pclass  \
# 0              1         0     1       3
# 1              2         1     3       1
# 2              3         1     4       3
# 3            892         0   892       3
# 4              4         1     5       1
# ..           ...       ...   ...     ...
# 887          887         0   887       2
# 888          888         1   889       1
# 889          889         0   889       3
# 890          890         1   891       1
# 891          891         0   891       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                                                 abcd  famale  34.0      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...
